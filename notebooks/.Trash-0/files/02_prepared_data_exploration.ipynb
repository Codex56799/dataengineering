# %% [markdown]
# ### Connect to DuckDB and Configure S3/MinIO Access
#
# The following cell initializes a DuckDB connection backed by a local database file and enables the `httpfs` extension to read and write data stored in MinIO via the S3 API. It sets the MinIO endpoint, disables SSL, applies path-style addressing, and loads S3 access credentials from environment variables.

# %%
import os
import duckdb

os.makedirs("/opt/de_project/warehouse", exist_ok=True)
db_path = "/opt/de_project/warehouse/taxi.duckdb"
con = duckdb.connect(db_path)

# Enable S3/MinIO access via DuckDB's httpfs extension
con.execute("INSTALL httpfs;")
con.execute("LOAD httpfs;")

# Configure DuckDB to connect to MinIO
con.execute("SET s3_endpoint = 'minio:9000';")
con.execute("SET s3_use_ssl = false;")
con.execute("SET s3_url_style = 'path';")

# Credentials
con.execute(f"SET s3_access_key_id = '{os.environ['AWS_ACCESS_KEY_ID']}';")
con.execute(f"SET s3_secret_access_key = '{os.environ['AWS_SECRET_ACCESS_KEY']}';")

con

# %%
row_count = con.execute("SELECT COUNT(*) FROM taxi.taxi.trips_prepared;").fetchone()[0]
row_count
# Out:
# 2928254

# %% [markdown]
# ### Sample 100 rows from the prepared Taxi Table
#
# The next cell queries a subset of the prepared dataset from DuckDB, retrieves the results as a Pandas DataFrame, and displays the first few rows for inspection.

# %%
q = """
SELECT
    *
FROM taxi.taxi.trips_prepared
LIMIT 100;
"""
df = con.execute(q).fetchdf()
df.head()
# Out:
#    DOLocationID  PULocationID  VendorID tpep_pickup_datetime  \
# 0           170           170         2  2002-12-31 22:59:39
# 1           264           137         2  2009-01-01 23:58:40
# 2           264           237         2  2009-01-01 23:30:39
# 3           264           138         2  2009-01-01 00:24:09
# 4           142           236         2  2023-12-31 23:56:46
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2002-12-31 23:05:41                1           0.63           1
# 1   2009-01-02 00:01:40                1           0.46           1
# 2   2009-01-02 00:01:39                1          10.99           1
# 3   2009-01-01 01:13:00                2          10.88           1
# 4   2024-01-01 00:12:06                2           2.38           1
#
#   store_and_fwd_flag  payment_type  ...    avg_mph  PU_Borough  \
# 0                  N             3  ...   6.265193   Manhattan
# 1                  N             2  ...   9.200000   Manhattan
# 2                  N             2  ...  21.270968   Manhattan
# 3                  N             2  ...  13.363357      Queens
# 4                  N             1  ...   9.313043   Manhattan
#
#                  PU_Zone  PU_service_zone  DO_Borough              DO_Zone  \
# 0            Murray Hill      Yellow Zone   Manhattan          Murray Hill
# 1               Kips Bay      Yellow Zone     Unknown                  N/A
# 2  Upper East Side South      Yellow Zone     Unknown                  N/A
# 3      LaGuardia Airport         Airports     Unknown                  N/A
# 4  Upper East Side North      Yellow Zone   Manhattan  Lincoln Square East
#
#    DO_service_zone  month  pickup_date  year
# 0      Yellow Zone     01   2002-12-31  2024
# 1              N/A     01   2009-01-01  2024
# 2              N/A     01   2009-01-01  2024
# 3              N/A     01   2009-01-01  2024
# 4      Yellow Zone     01   2023-12-31  2024
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DOLocationID           100 non-null    int32
#  1   PULocationID           100 non-null    int32
#  2   VendorID               100 non-null    int32
#  3   tpep_pickup_datetime   100 non-null    datetime64[us]
#  4   tpep_dropoff_datetime  100 non-null    datetime64[us]
#  5   passenger_count        57 non-null     Int32
#  6   trip_distance          100 non-null    float64
#  7   RatecodeID             57 non-null     Int32
#  8   store_and_fwd_flag     57 non-null     object
#  9   payment_type           100 non-null    int32
#  10  fare_amount            100 non-null    float64
#  11  extra                  100 non-null    float64
#  12  mta_tax                100 non-null    float64
#  13  tip_amount             100 non-null    float64
#  14  tolls_amount           100 non-null    float64
#  15  improvement_surcharge  100 non-null    float64
#  16  total_amount           100 non-null    float64
#  17  congestion_surcharge   57 non-null     float64
#  18  Airport_fee            57 non-null     float64
#  19  pickup_hour            100 non-null    int32
#  20  dropoff_date           100 non-null    datetime64[us]
#  21  trip_duration_min      100 non-null    float64
#  22  avg_mph                100 non-null    float64
#  23  PU_Borough             100 non-null    object
#  24  PU_Zone                100 non-null    object
#  25  PU_service_zone        100 non-null    object
#  26  DO_Borough             100 non-null    object
#  27  DO_Zone                100 non-null    object
#  28  DO_service_zone        100 non-null    object
#  29  month                  100 non-null    object
#  30  pickup_date            100 non-null    datetime64[us]
#  31  year                   100 non-null    int64
# dtypes: Int32(2), datetime64[us](4), float64(12), int32(5), int64(1), object(8)
# memory usage: 22.6+ KB

# %% [markdown]
# ### Descriptive statistics of the sampled dataset
#
# The following cell computes summary statistics for all numeric columns in the DataFrame, allowing you to quickly inspect distributions, ranges, and potential data quality issues.

# %%
df.describe()
# Out:
#        DOLocationID  PULocationID    VendorID        tpep_pickup_datetime  \
# count    100.000000    100.000000  100.000000                         100
# mean     159.410000    165.580000    1.530000  2023-05-05 00:02:13.920000
# min        4.000000      4.000000    1.000000         2002-12-31 22:59:39
# 25%       87.000000    122.250000    1.000000  2024-01-01 00:15:59.250000
# 50%      156.000000    158.000000    2.000000  2024-01-01 00:36:27.500000
# 75%      236.250000    236.000000    2.000000  2024-01-01 00:49:31.750000
# max      265.000000    263.000000    2.000000         2024-01-01 00:58:16
# std       76.163447     66.805338    0.501614                         NaN
#
#             tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# count                         100             57.0     100.000000        57.0
# mean   2023-05-05 00:19:05.920000          1.45614       2.497800    1.070175
# min           2002-12-31 23:05:41              0.0       0.000000         1.0
# 25%    2024-01-01 00:32:46.750000              1.0       0.400000         1.0
# 50%    2024-01-01 00:52:42.500000              1.0       1.470000         1.0
# 75%    2024-01-01 01:05:32.750000              2.0       2.970000         1.0
# max           2024-01-01 01:39:00              6.0      23.900000         5.0
# std                           NaN         0.867471       3.508533    0.529813
#
#        payment_type  fare_amount  ...  improvement_surcharge  total_amount  \
# count    100.000000   100.000000  ...                  100.0      100.0000
# mean       0.770000    20.096300  ...                    1.0       26.8229
# min        0.000000     3.000000  ...                    1.0        8.0000
# 25%        0.000000    10.000000  ...                    1.0       16.4100
# 50%        1.000000    15.950000  ...                    1.0       22.0200
# 75%        1.000000    28.330000  ...                    1.0       32.7675
# max        4.000000   120.000000  ...                    1.0      127.9400
# std        0.814701    15.515665  ...                    0.0       17.4750
#
#        congestion_surcharge  Airport_fee  pickup_hour         dropoff_date  \
# count             57.000000    57.000000   100.000000                  100
# mean               2.192982     0.092105     2.980000  2023-05-04 22:33:36
# min                0.000000     0.000000     0.000000  2002-12-31 00:00:00
# 25%                2.500000     0.000000     0.000000  2024-01-01 00:00:00
# 50%                2.500000     0.000000     0.000000  2024-01-01 00:00:00
# 75%                2.500000     0.000000     0.000000  2024-01-01 00:00:00
# max                2.500000     1.750000    23.000000  2024-01-01 00:00:00
# std                0.827833     0.394243     7.748548                  NaN
#
#        trip_duration_min     avg_mph          pickup_date    year
# count         100.000000  100.000000                  100   100.0
# mean           16.866667    8.928686  2023-05-04 20:24:00  2024.0
# min             0.316667    0.000000  2002-12-31 00:00:00  2024.0
# 25%             7.012500    3.247443  2024-01-01 00:00:00  2024.0
# 50%            13.250000    7.944843  2024-01-01 00:00:00  2024.0
# 75%            22.337500   12.059567  2024-01-01 00:00:00  2024.0
# max            62.050000   41.285988  2024-01-01 00:00:00  2024.0
# std            12.410828    8.067017                  NaN     0.0
#
# [8 rows x 24 columns]

# %% [markdown]
# ### Temporal Coverage Validation
#
# Confirm whether the dataset covers the full expected day/hour range.
# This helps detect missing ingestion or partition issues.

# %%
con.execute("""
SELECT 
    MIN(pickup_date) AS min_date,
    MAX(pickup_date) AS max_date,
    COUNT(DISTINCT pickup_hour) AS distinct_hours
FROM taxi.taxi.trips_prepared;
""").fetchdf()
# Out:
#     min_date   max_date  distinct_hours
# 0 2002-12-31 2024-02-01              24

# %% [markdown]
# ### Hourly aggregation
#
# This query aggregates trips by pickup date and hour, computing trip counts and average metrics. The resulting DataFrame preview below helps confirm that the transformation and DuckDB ingestion produced coherent time-based features.

# %%
q = """
SELECT
    pickup_date,
    pickup_hour,
    COUNT(*) AS trips,
    AVG(trip_distance) AS avg_distance_miles,
    AVG(total_amount) AS avg_total_amount
FROM taxi.taxi.trips_prepared
GROUP BY 1, 2
ORDER BY 1, 2
LIMIT 100;
"""
df_hourly = con.execute(q).fetchdf()
df_hourly.head()
# Out:
#   pickup_date  pickup_hour  trips  avg_distance_miles  avg_total_amount
# 0  2002-12-31           22      1             0.63000         10.500000
# 1  2009-01-01            0      1            10.88000         68.290000
# 2  2009-01-01           23      2             5.72500         29.700000
# 3  2023-12-31           23     10             2.60100         22.462000
# 4  2024-01-01            0   6523             2.94086         27.438436
